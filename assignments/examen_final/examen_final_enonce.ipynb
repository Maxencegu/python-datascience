# %% [markdown]
# [![Lancer dans Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/Maxencegu/python-datascience/main?labpath=assignments%2Fexamen_final%2Fexamen_final_enonce.ipynb)
#
# # 🎓 Examen Final — Python & Data Science
#
# **Durée : 2 heures | 200 points**
# **Cours :** Python & Data Science — L3/M1 Économie, UPJV Amiens
#
# ---
#
# ### ⚠️ Consignes
#
# - Cet examen est **individuel**. Toute communication avec d'autres étudiants est interdite.
# - **Commencez par exécuter la cellule de configuration** (première cellule de code ci-dessous).
# - Remplacez chaque `___` par votre code. Ne modifiez pas le reste.
# - Vous pouvez consulter les infographies disponibles sur le dépôt du cours.
# - Les consignes de remise sont en **dernière cellule** du notebook.
#
# ### Barème
#
# | Partie | Thème | Points |
# |--------|-------|--------|
# | Partie 1 | Python & NumPy | 50 pts |
# | Partie 2 | Matplotlib & Pandas | 70 pts |
# | Partie 3 | Pandas avancé | 80 pts |
# | **Total** | | **200 pts** |
#
# | Exercice | Thème | Points |
# |----------|-------|--------|
# | Ex 1 | Fonctions Python (return + compréhension de liste) | 20 pts |
# | Ex 2 | NumPy (moyenne, filtrage, calcul vectorisé) | 30 pts |
# | Ex 3 | Matplotlib (histogramme, titre, labels) | 30 pts |
# | Ex 4 | Pandas — sélection & filtrage | 40 pts |
# | Ex 5 | Nouvelles colonnes & .agg() | 30 pts |
# | Ex 6 | .groupby() — une et deux variables | 26 pts |
# | Ex 7 | .pivot_table() avec fill_value et margins | 24 pts |
#
# ### Contexte des données
#
# Vous disposez d'un DataFrame `sales` contenant des ventes hebdomadaires d'une chaîne de supermarchés américaine :
#
# | Colonne | Description |
# |---------|-------------|
# | `store` | Numéro du magasin |
# | `type` | Type de magasin (A, B ou C) |
# | `department` | Numéro du département |
# | `date` | Date de la semaine |
# | `weekly_sales` | Ventes hebdomadaires (USD) |
# | `is_holiday` | Semaine de vacances (`True` / `False`) |
# | `temperature_c` | Température (°C) |
# | `fuel_price_usd_per_l` | Prix du carburant (USD/L) |
# | `unemployment` | Taux de chômage (%) |

# %%
# @title ⚙️ Configuration — exécuter en premier (ne pas modifier)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request

urllib.request.urlretrieve(
    "https://raw.githubusercontent.com/Maxencegu/python-datascience/main/datasets/sales_subset.csv",
    "sales_subset.csv"
)
sales = pd.read_csv("sales_subset.csv", index_col=0)
print("✅ Environnement prêt —", sales.shape[0], "lignes,", sales.shape[1], "colonnes.")

# %% [markdown]
# ---
#
# ## Partie 1 — Python & NumPy `50 points`

# %% [markdown]
# ---
#
# ---
#
# ### **Exercice 1 — Fonctions Python** `20 points`
#
# En Python, une **fonction** encapsule une opération réutilisable. Elle peut retourner une valeur avec `return`.
# Une **compréhension de liste** `[expr for x in liste]` permet d'appliquer une expression à chaque élément d'une liste.
#
# ---
#
# ### **Instructions**
#
# **Étape 1/3 (8 pts)** — Écrire la fonction `objectif_atteint(ventes, seuil)` qui retourne `True` si `ventes > seuil`, `False` sinon.
#
# **Étape 2/3 (6 pts)** — Tester la fonction : `objectif_atteint(15000, 10000)` doit afficher `True` ; `objectif_atteint(5000, 10000)` doit afficher `False`.
#
# **Étape 3/3 (6 pts)** — Appliquer la fonction à la liste `ventes_semaine` avec une **compréhension de liste**, en utilisant le seuil `10000`.

# %%
# ----------------------------------------------------------------
# Étape 1/3 — Définir la fonction objectif_atteint
# ----------------------------------------------------------------
def objectif_atteint(ventes, seuil):
    return ___

# ----------------------------------------------------------------
# Étape 2/3 — Tester la fonction
# ----------------------------------------------------------------
print(objectif_atteint(15000, 10000))  # attendu : True
print(objectif_atteint(5000, 10000))   # attendu : False

# ----------------------------------------------------------------
# Étape 3/3 — Appliquer à la liste avec une compréhension de liste
# ----------------------------------------------------------------
ventes_semaine = [8500, 12000, 6700, 23000, 9800]
resultats = [___ for v in ventes_semaine]
print(resultats)

# %% [markdown]
# ---
#
# ---
#
# ### **Exercice 2 — NumPy** `30 points`
#
# **NumPy** permet d'effectuer des calculs sur des tableaux entiers sans boucle explicite.
# Un tableau NumPy supporte les opérations arithmétiques vectorisées et le filtrage par condition booléenne.
#
# ---
#
# ### **Instructions**
#
# **Étape 1/3 (10 pts)** — Calculer la **moyenne** du tableau `temperatures` avec NumPy et la stocker dans `temp_moyenne`.
#
# **Étape 2/3 (10 pts)** — Filtrer les températures **strictement supérieures à 20°C** et stocker le résultat dans `temp_chaudes`.
#
# **Étape 3/3 (10 pts)** — Calculer l'**écart à la moyenne** pour chaque valeur (soustraction vectorisée) et stocker dans `ecarts`.

# %%
temperatures = np.array([12.5, 8.3, 15.7, 22.1, 18.9, 5.2, 28.4, 19.6, 14.3, 31.0])

# ----------------------------------------------------------------
# Étape 1/3 — Calculer la moyenne
# ----------------------------------------------------------------
temp_moyenne = ___
print("Moyenne :", temp_moyenne)

# ----------------------------------------------------------------
# Étape 2/3 — Filtrer les températures > 20°C
# ----------------------------------------------------------------
temp_chaudes = ___
print("Températures > 20°C :", temp_chaudes)

# ----------------------------------------------------------------
# Étape 3/3 — Calculer les écarts à la moyenne
# ----------------------------------------------------------------
ecarts = ___
print("Écarts à la moyenne :", ecarts)

# %% [markdown]
# ---
#
# ## Partie 2 — Matplotlib & Pandas `70 points`

# %% [markdown]
# ---
#
# ---
#
# ### **Exercice 3 — Matplotlib** `30 points`
#
# **Matplotlib** permet de créer des visualisations en Python.
# `plt.hist(data, bins=N)` trace un histogramme avec `N` classes. `plt.title()`, `plt.xlabel()` et `plt.ylabel()` personnalisent le graphique. `plt.show()` l'affiche.
#
# ---
#
# ### **Instructions**
#
# **Étape 1/4 (8 pts)** — Tracer un **histogramme** de la colonne `weekly_sales` avec **20 classes** (`bins=20`).
#
# **Étape 2/4 (8 pts)** — Ajouter le titre : `"Distribution des ventes hebdomadaires"`.
#
# **Étape 3/4 (8 pts)** — Ajouter le label de l'axe x : `"Ventes (USD)"` et de l'axe y : `"Nombre de semaines"`.
#
# **Étape 4/4 (6 pts)** — Afficher le graphique.

# %%
# ----------------------------------------------------------------
# Étape 1/4 — Histogramme de weekly_sales avec bins=20
# ----------------------------------------------------------------
plt.hist(___, bins=___)

# ----------------------------------------------------------------
# Étape 2/4 — Titre
# ----------------------------------------------------------------
plt.title(___)

# ----------------------------------------------------------------
# Étape 3/4 — Labels des axes
# ----------------------------------------------------------------
plt.xlabel(___)
plt.ylabel(___)

# ----------------------------------------------------------------
# Étape 4/4 — Afficher le graphique
# ----------------------------------------------------------------
___

# %% [markdown]
# ---
#
# ---
#
# ### **Exercice 4 — Sélection et filtrage** `40 points`
#
# Les méthodes de base de Pandas permettent d'**explorer** et de **sous-sectionner** un DataFrame.
# `.head()` affiche les premières lignes. `.shape` donne les dimensions. `df[["col1", "col2"]]` sélectionne des colonnes. `df[condition]` filtre les lignes.
#
# ---
#
# ### **Instructions**
#
# **Étape 1/4 (8 pts)** — Afficher les **5 premières lignes** du DataFrame `sales`.
#
# **Étape 2/4 (8 pts)** — Afficher les **dimensions** du DataFrame (nombre de lignes et de colonnes).
#
# **Étape 3/4 (12 pts)** — Sélectionner uniquement les colonnes `"store"`, `"type"` et `"weekly_sales"` et stocker dans `sales_reduit`.
#
# **Étape 4/4 (12 pts)** — Filtrer les lignes dont la colonne `type` vaut `"A"` et stocker dans `sales_type_a`.

# %%
# ----------------------------------------------------------------
# Étape 1/4 — 5 premières lignes
# ----------------------------------------------------------------
___

# ----------------------------------------------------------------
# Étape 2/4 — Dimensions
# ----------------------------------------------------------------
print(___)

# ----------------------------------------------------------------
# Étape 3/4 — Sélectionner les colonnes store, type et weekly_sales
# ----------------------------------------------------------------
sales_reduit = ___
print(sales_reduit.head())

# ----------------------------------------------------------------
# Étape 4/4 — Filtrer les magasins de type A
# ----------------------------------------------------------------
sales_type_a = ___
print("Lignes de type A :", len(sales_type_a))

# %% [markdown]
# ---
#
# ## Partie 3 — Pandas avancé `80 points`

# %% [markdown]
# ---
#
# ---
#
# ### **Exercice 5 — Nouvelles colonnes et statistiques** `30 points`
#
# Pandas permet de **créer des colonnes** dérivées de colonnes existantes et de calculer des **statistiques récapitulatives** avec des méthodes directes ou `.agg()`.
#
# ---
#
# ### **Instructions**
#
# **Étape 1/3 (10 pts)** — Créer une nouvelle colonne `"weekly_sales_k"` contenant les valeurs de `weekly_sales` divisées par `1000`.
#
# **Étape 2/3 (10 pts)** — Calculer la **moyenne** et la **médiane** de `"weekly_sales_k"` et les afficher.
#
# **Étape 3/3 (10 pts)** — Calculer le minimum, le maximum et la moyenne de `"weekly_sales"` en une **seule opération `.agg()`** et afficher le résultat.

# %%
# ----------------------------------------------------------------
# Étape 1/3 — Créer la colonne weekly_sales_k
# ----------------------------------------------------------------
sales["weekly_sales_k"] = ___

# ----------------------------------------------------------------
# Étape 2/3 — Moyenne et médiane de weekly_sales_k
# ----------------------------------------------------------------
moyenne = ___
mediane = ___
print("Moyenne (k$) :", round(moyenne, 2))
print("Médiane (k$) :", round(mediane, 2))

# ----------------------------------------------------------------
# Étape 3/3 — .agg() avec min, max et mean
# ----------------------------------------------------------------
recap = sales["weekly_sales"].agg(___)
print(recap)

# %% [markdown]
# ---
#
# ---
#
# ### **Exercice 6 — Statistiques groupées** `26 points`
#
# `.groupby()` permet de **calculer des statistiques par groupe**, sans répéter le code pour chaque catégorie.
# Syntaxe : `df.groupby("col_groupe")["col_valeur"].methode()`
#
# ---
#
# ### **Instructions**
#
# **Étape 1/2 (12 pts)** — Calculer la **moyenne** de `weekly_sales` par **type de magasin** et afficher le résultat.
#
# **Étape 2/2 (14 pts)** — Calculer le **minimum** et le **maximum** de `weekly_sales` en groupant par `type` ET par `is_holiday`, et afficher le résultat.

# %%
# ----------------------------------------------------------------
# Étape 1/2 — Moyenne de weekly_sales par type de magasin
# ----------------------------------------------------------------
ventes_par_type = ___
print(ventes_par_type)

# ----------------------------------------------------------------
# Étape 2/2 — Min et max par type et is_holiday
# ----------------------------------------------------------------
ventes_groupe = ___
print(ventes_groupe)

# %% [markdown]
# ---
#
# ---
#
# ### **Exercice 7 — Tableau croisé dynamique** `24 points`
#
# `.pivot_table()` présente des statistiques groupées sous forme de **tableau à double entrée**.
# L'argument `fill_value` remplace les valeurs manquantes. L'argument `margins=True` ajoute une ligne et une colonne `"All"` avec les totaux.
#
# ---
#
# ### **Instructions**
#
# Créer un tableau croisé dynamique avec :
# - `values` = `"weekly_sales"`
# - `index` = `"type"`
# - `columns` = `"is_holiday"`
# - `fill_value` = `0`
# - `margins` = `True`
#
# Stocker le résultat dans `pivot` et l'afficher.

# %%
# ----------------------------------------------------------------
# Créer le tableau croisé dynamique
# ----------------------------------------------------------------
pivot = sales.pivot_table(
    values=___,
    index=___,
    columns=___,
    fill_value=___,
    margins=___
)
print(pivot)

# %% [markdown]
# ---
#
# ## 📤 Remise du travail
#
# Une fois tous les exercices terminés, suivez ces étapes **dans l'ordre**.
#
# ### Étape 1 — Sauvegarder et télécharger le notebook depuis Binder
#
# 1. Sauvegardez : **Ctrl+S** (ou **File → Save Notebook**)
# 2. Téléchargez : **File → Download**
# 3. Le fichier `examen_final_enonce.ipynb` est enregistré sur votre ordinateur
#
# ### Étape 2 — Déposer sur votre dépôt GitHub
#
# 1. Allez sur votre dépôt `upjv-python-datascience` sur GitHub
# 2. Créez une nouvelle branche `examen_final` depuis `main`
# 3. Sur cette branche, cliquez sur **Add file → Upload files**
# 4. Déposez le fichier `examen_final_enonce.ipynb`
# 5. Message de commit : `Examen final`
# 6. Cliquez sur **Commit changes**
#
# ### Étape 3 — Ouvrir une Pull Request
#
# 1. Cliquez sur **Compare & pull request**
# 2. Vérifiez que la base est `main` et la branche source est `examen_final`
# 3. Titre de la PR : `Examen final — [Votre Prénom Nom]`
# 4. Dans **Reviewers**, ajoutez **l'enseignant** comme reviewer
# 5. Cliquez sur **Create pull request**
#
# > ⚠️ **Le timestamp du commit fait foi.** Tout dépôt effectué après la fin de l'examen ne sera pas pris en compte.
# > La PR sera validée par l'enseignant après correction — ne la mergez pas vous-même.
